# %%
import pandas as pd
from sklearn.decomposition import PCA

# %%
main_data = pd.read_excel("/Users/chuhanli/Documents/GitHub/HousingFoward/main_data.csv")
finance_data = pd.read_csv("/Users/chuhanli/Documents/GitHub/HousingFoward/finance_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/chuhanli/Documents/GitHub/HousingFoward/ranking.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/chuhanli/Documents/GitHub/HousingFoward/ranking.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> main_data = pd.read_excel("/Users/chuhanli/Documents/GitHub/HousingFoward/main_data.csv")
#       <a href='vscode-notebook-cell:/Users/chuhanli/Documents/GitHub/HousingFoward/ranking.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> finance_data = pd.read_csv("/Users/chuhanli/Documents/GitHub/HousingFoward/finance_data.csv")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
# ...

# %%
finance_data
# Out:
#    Municipality  Single family value  Single family parcel  \
# 0      Abington         1.324427e+09           3789.000000
# 1       Andover         5.369069e+09           8615.857143
# 2          Ayer         5.163446e+08           1605.555556
# 3       Belmont         4.802108e+09           4523.000000
# 4       Beverly         4.156975e+09           8485.333333
# 5     Braintree         4.140620e+09           9061.111111
# 6      Brockton         4.159996e+09          16614.000000
# 7        Canton         2.883704e+09           5407.555556
# 8       Chelsea         2.201653e+08            835.000000
# 9       Concord         4.473480e+09           4590.666667
# 10       Dedham         3.172285e+09           6607.333333
# 11      Everett         1.018990e+09           2702.000000
# 12     Franklin         3.306308e+09           7703.000000
# 13      Hingham         4.920432e+09           6215.555556
# 14     Kingston         1.606018e+09           3970.700000
# ...

# %%
sorted_ = finance_data.sort_values(by = ["Avg tax bill over income	 "], ascending = True)
sorted_
# Out:
#    Municipality  Single family value  Single family parcel  \
# 11      Everett         1.018990e+09           2702.000000
# 21     Rockport         1.450759e+09           2395.111111
# 5     Braintree         4.140620e+09           9061.111111
# 17       Newton         1.834406e+10          16957.444444
# 24      Waltham         3.633604e+09           8740.000000
# 18      Norwood         2.581986e+09           5844.111111
# 25    Wellesley         9.242472e+09           7297.444444
# 22     Stoneham         2.558688e+09           5121.222222
# 13      Hingham         4.920432e+09           6215.555556
# 16      Needham         7.521628e+09           8390.222222
# 3       Belmont         4.802108e+09           4523.000000
# 29   Winchester         5.833374e+09           5648.222222
# 27     Weymouth         4.834184e+09          13301.666667
# 7        Canton         2.883704e+09           5407.555556
# 23    Wakefield         3.079989e+09           6244.875000
# ...

# %%
sorted_["Municipality"]
# Out:
# 8        Chelsea
# 11       Everett
# 6       Brockton
# 28       Whitman
# 2           Ayer
# 20        Quincy
# 27      Weymouth
# 0       Abington
# 19      Plymouth
# 24       Waltham
# 14      Kingston
# 5      Braintree
# 18       Norwood
# 22      Stoneham
# 4        Beverly
# 23     Wakefield
# 21      Rockport
# 15     Mansfield
# 12      Franklin
# 10        Dedham
# 7         Canton
# 1        Andover
# 3        Belmont
# 29    Winchester
# 13       Hingham
# 16       Needham
# 26      Westwood
# 17        Newton
# 9        Concord
# 25     Wellesley
# Name: Municipality, dtype: object
